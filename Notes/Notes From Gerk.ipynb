# %% [markdown]
# # Notes from Gerken - Dealing with data availibility
# longer datasets from Daymet.ornl.gov
#
# https://search.earthdata.nasa.gov/search?q=Daymet_Daily_V4R1_2129&ac=true&lat=25.235128988137323&long=-89.9656458641448&zoom=2.954411339362462
#
# take 10 years we have and align with larger daymet dataset, compare how well they align. think about correlation, if you plot against each other you see how well they agree. if they do so well that is a result. the opposite is an other result. the answer to the question doesn't matter.
#
# Then look at spacial scales, for a product like that you can look at how does precipitation and temp change as you go from harrisonburg up the mountain. Correlation between precip. and sub zero temps, seasonalityof precipitation - when do you care when you get it.
#
# Daymet might now give snow data, so think when does the rain fall. how many days per year do you have days below freezing, counts of days.
# Degree days are sums of a season the total temps below zero.
#
# Again compare observed data to spatial dataset. How much more or less you are getting spatially because you are in the mountain or not.
